# %%
import pandas

# %%
df=pandas.read_csv("GFDDData.csv")
df
# Out:
#       Country Name Country Code  \
# 0      Afghanistan          AFG
# 1      Afghanistan          AFG
# 2      Afghanistan          AFG
# 3      Afghanistan          AFG
# 4      Afghanistan          AFG
# ...            ...          ...
# 25033     Zimbabwe          ZWE
# 25034     Zimbabwe          ZWE
# 25035     Zimbabwe          ZWE
# 25036     Zimbabwe          ZWE
# 25037     Zimbabwe          ZWE
#
#                                           Indicator Name Indicator Code  1960  \
# 0                             5-bank asset concentration     GFDD.OI.06   NaN
# 1      Account at a formal financial institution (% a...     GFDD.AI.05   NaN
# 2         Account used for business purposes (% age 15+)     GFDD.AI.08   NaN
# 3      Account used to receive government payments (%...     GFDD.AI.09   NaN
# 4        Account used to receive remittances (% age 15+)     GFDD.AI.10   NaN
# ...                                                  ...            ...   ...
# ...
